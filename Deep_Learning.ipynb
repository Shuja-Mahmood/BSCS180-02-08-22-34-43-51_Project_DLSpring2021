# %% [markdown]
# <a href="https://colab.research.google.com/github/Shuja-Mahmood/BSCS180-02-08-22-34-43-51_Project_DLSpring2021/blob/main/Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/MyDrive/Colab\ Notebooks
! ls
# Out:
# [Errno 2] No such file or directory: 'gdrive/MyDrive/Colab Notebooks'
# /content/gdrive/MyDrive/Colab Notebooks/yolov5
# check.py	 export.py    README.md		train.py	Wheat.yaml
# CONTRIBUTING.md  hubconf.py   requirements.txt	tutorial.ipynb	yolov5l.pt
# data		 LICENSE      runs		utils		yolov5s.pt
# detect.py	 models       testingYOLO5.py	val.py
# Dockerfile	 __pycache__  test.py		Wheat_data

# %%
! git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 7633, done.
# remote: Counting objects: 100% (353/353), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 7633 (delta 221), reused 271 (delta 188), pack-reused 7280
# Receiving objects: 100% (7633/7633), 9.05 MiB | 9.46 MiB/s, done.
# Resolving deltas: 100% (5237/5237), done.

# %%
# %cd yolov5/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/yolov5

# %%
! python train.py --img 1024 --batch 8 --epochs 10 --data Wheat.yaml --cfg models/yolov5m.yaml --name wm
# Out:
# train: weights=yolov5s.pt, cfg=models/yolov5m.yaml, data=Wheat.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=10, batch_size=8, img_size=[1024], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=wm, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2021-6-27 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
! python detect.py --source Wheat_data/images/validation --weights runs/train/wm8/weights/best.pt
# Out:
# detect: weights=['runs/train/wm8/weights/best.pt'], source=Wheat_data/images/validation, imgsz=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 2021-6-27 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 308 layers, 21037638 parameters, 0 gradients
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...

# %%
! python test.py --weights runs/train/wm8/weights/best.pt --data Wheat.yaml --img 1024
# Out:
# test: data=Wheat.yaml, weights=['runs/train/wm8/weights/best.pt'], batch_size=32, imgsz=1024, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/test, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2021-6-27 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 308 layers, 21037638 parameters, 0 gradients
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...

# %%
! python train.py --img 1024 --batch 8 --epochs 10 --data Wheat.yaml --cfg models/yolov5l.yaml --name wm --weights yolov5l.pt
# Out:
# train: weights=yolov5l.pt, cfg=models/yolov5l.yaml, data=Wheat.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=10, batch_size=8, img_size=[1024], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=wm, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2021-6-27 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
! python detect.py --source Wheat_data/images/validation --weights runs/train/wm19/weights/best.pt
# Out:
# detect: weights=['runs/train/wm19/weights/best.pt'], source=Wheat_data/images/validation, imgsz=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 2021-6-27 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46600566 parameters, 0 gradients
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...

# %%
! python detect.py --source Wheat_data/images/validation --weights runs/train/wm19/weights/best.pt runs/train/wm8/weights/best.pt
# Out:
# detect: weights=['runs/train/wm19/weights/best.pt', 'runs/train/wm8/weights/best.pt'], source=Wheat_data/images/validation, imgsz=640, conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 2021-8-7 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46600566 parameters, 0 gradients
# Fusing layers...
# Model Summary: 308 layers, 21037638 parameters, 0 gradients
# Ensemble created with ['runs/train/wm19/weights/best.pt', 'runs/train/wm8/weights/best.pt']
#
# ...

# %%
! python test.py --weights runs/train/wm19/weights/best.pt --data Wheat.yaml --img 1024
# Out:
# test: data=Wheat.yaml, weights=['runs/train/wm19/weights/best.pt'], batch_size=32, imgsz=1024, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/test, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2021-8-7 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46600566 parameters, 0 gradients
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ...

# %%
! python test.py --weights runs/train/wm19/weights/best.pt runs/train/wm8/weights/best.pt --data Wheat.yaml --img 1024
# Out:
# test: data=Wheat.yaml, weights=['runs/train/wm19/weights/best.pt', 'runs/train/wm8/weights/best.pt'], batch_size=32, imgsz=1024, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/test, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 2021-8-7 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46600566 parameters, 0 gradients
# Fusing layers...
# Model Summary: 308 layers, 21037638 parameters, 0 gradients
# Ensemble created with ['runs/train/wm19/weights/best.pt', 'runs/train/wm8/weights/best.pt']
#
# ...
